# %% [markdown]
# <a href="https://colab.research.google.com/github/camilalarrosa/Caderno_para_aprender_Python/blob/main/unicorns_case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case_unicorns
#
# Análise de startups que se tornaram unicórnios

# %% [markdown]
# # **Sobre o conjunto de dados** <p>
# "Unicórnio" é um termo usado na indústria de capital de risco para descrever uma startup de capital fechado com valor superior a US$ 1 bilhão. O termo foi popularizado pela primeira vez pela capitalista de risco Aileen Lee, fundadora da Cowboy Ventures, um fundo de capital de risco com sede em Palo Alto, Califórnia.
#
# Unicórnios também podem se referir a um fenômeno de recrutamento no setor de recursos humanos (RH). Os gerentes de RH podem ter grandes expectativas para preencher um cargo, levando-os a procurar candidatos com qualificações superiores às exigidas para um cargo específico. Em essência, esses gerentes estão procurando um unicórnio, o que leva a uma desconexão entre seu candidato ideal e quem eles podem contratar do grupo de pessoas disponíveis.
#
# [Download da base de dados](https://www.kaggle.com/ramjasmaurya/unicorn-startups)

# %%
# Importar as libs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Ler os dados
Base_Dados = pd.read_csv('/content/sample_data/Startups+in+2021+end.csv')

# Verificar Dimensão
Base_Dados.shape
# Out:
# (936, 8)

# %%
# Verificando os primeiros registros da base de dados
Base_Dados.head()
# Out:
#    Unnamed: 0    Company Valuation ($B) Date Joined        Country  \
# 0           0  Bytedance           $140    4/7/2017          China
# 1           1     SpaceX         $100.3   12/1/2012  United States
# 2           2     Stripe            $95   1/23/2014  United States
# 3           3     Klarna          $45.6  12/12/2011         Sweden
# 4           4      Canva            $40    1/8/2018      Australia
#
#             City                      Industry  \
# 0        Beijing       Artificial intelligence
# 1      Hawthorne                         Other
# 2  San Francisco                       Fintech
# 3      Stockholm                       Fintech
# 4    Surry Hills  Internet software & services
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# ...

# %%
# Verificando as Colunas
Base_Dados.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'Valuation ($B)', 'Date Joined', 'Country',
#        'City', 'Industry', 'Select Investors'],
#       dtype='object')

# %%
# Renomeando as colunas
Base_Dados.rename( columns={
    'Unnamed: 0' : 'Id',
    'Company' : 'Empresa',
    'Valuation ($B)' : 'Valor ($)',
    'Date Joined' : 'Data de Adesão',
    'Country' : 'Pais',
    'City' : 'Cidade',
    'Industry': 'Setor',
    'Select Investors': 'Investidores',
}, inplace=True )
# inplace=True --> estou aplicando as mudanças na base de dados de origem

# %%
# Verificar Tipo de informação
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              936 non-null    int64
#  1   Empresa         936 non-null    object
#  2   Valor ($)       936 non-null    object
#  3   Data de Adesão  936 non-null    object
#  4   Pais            936 non-null    object
#  5   Cidade          921 non-null    object
#  6   Setor           936 non-null    object
#  7   Investidores    935 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 58.6+ KB

# %%
# Verificando os Campos nulos
Base_Dados.isnull().sum()

# tenho poucos campos nulos, aparentemente não vai interferir na
# minha análise
# Out:
# Id                 0
# Empresa            0
# Valor ($)          0
# Data de Adesão     0
# Pais               0
# Cidade            15
# Setor              0
# Investidores       1
# dtype: int64

# %%
# visualização Grafica dos campos nulos
plt.figure( figsize=(15,6) )
plt.title('Analisando Campos Nulos')
sns.heatmap( Base_Dados.isnull(), cbar=False );

# %%
# Campos unicos na base de dados
Base_Dados.nunique()
# Out:
# Id                936
# Empresa           935
# Valor ($)         192
# Data de Adesão    589
# Pais               47
# Cidade            239
# Setor              17
# Investidores      920
# dtype: int64

# %%
# Tipos de Valores Unicos em uma coluna -- ex: setor
Base_Dados['Setor'].unique()
# Out:
# array(['Artificial intelligence', 'Other', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics', 'Edtech',
#        'E-commerce & direct-to-consumer', 'Hardware', 'Health',
#        'Consumer & retail', 'Auto & transportation', 'Finttech',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Artificial Intelligence'], dtype=object)

# %%
# Valores Unicos - Rank
# contando quantas vezes aquele valor único aparece
# na minha base de dados:
Base_Dados['Setor'].value_counts()
# Out:
# Fintech                                190
# Internet software & services           167
# E-commerce & direct-to-consumer        102
# Artificial intelligence                 69
# Health                                  63
# Supply chain, logistics, & delivery     51
# Other                                   51
# Cybersecurity                           41
# Mobile & telecommunications             37
# Data management & analytics             36
# Hardware                                32
# Auto & transportation                   29
# Edtech                                  27
# Consumer & retail                       23
# Travel                                  13
# Artificial Intelligence                  4
# Finttech                                 1
# Name: Setor, dtype: int64

# %%
# Valores Unicos - Rank (em %)
Base_Dados['Setor'].value_counts( normalize=True )
# Out:
# Fintech                                0.202991
# Internet software & services           0.178419
# E-commerce & direct-to-consumer        0.108974
# Artificial intelligence                0.073718
# Health                                 0.067308
# Supply chain, logistics, & delivery    0.054487
# Other                                  0.054487
# Cybersecurity                          0.043803
# Mobile & telecommunications            0.039530
# Data management & analytics            0.038462
# Hardware                               0.034188
# Auto & transportation                  0.030983
# Edtech                                 0.028846
# Consumer & retail                      0.024573
# Travel                                 0.013889
# Artificial Intelligence                0.004274
# Finttech                               0.001068
# Name: Setor, dtype: float64

# %%
# Visualizando com um gráfico de barras
plt.figure( figsize=(15,6) )
plt.title('Analise dos Setores')
plt.bar( Base_Dados['Setor'].value_counts().index, Base_Dados['Setor'].value_counts()  )
plt.xticks( rotation=45, ha='right' ); # rotacionar legenda 45 graus pra direita

# %%
Base_Dados['Pais'].value_counts()
# Out:
# United States           477
# China                   169
# India                    51
# United Kingdom           37
# Germany                  23
# Israel                   21
# France                   19
# Canada                   15
# Brazil                   15
# South Korea              11
# Singapore                11
# Hong Kong                 7
# Japan                     6
# Australia                 6
# Mexico                    5
# Netherlands               5
# Indonesia                 4
# Spain                     4
# Sweden                    4
# Switzerland               4
# Ireland                   3
# United Arab Emirates      3
# Norway                    3
# Belgium                   2
# Thailand                  2
# Denmark                   2
# Philippines               2
# Finland                   2
# Colombia                  2
# South Africa              2
# Turkey                    2
# Austria                   2
# Chile                     1
# ...

# %%
Analise = round( Base_Dados['Pais'].value_counts( normalize=True ) * 100, 1 )

# %%
Analise
# Out:
# United States           51.0
# China                   18.1
# India                    5.4
# United Kingdom           4.0
# Germany                  2.5
# Israel                   2.2
# France                   2.0
# Canada                   1.6
# Brazil                   1.6
# South Korea              1.2
# Singapore                1.2
# Hong Kong                0.7
# Japan                    0.6
# Australia                0.6
# Mexico                   0.5
# Netherlands              0.5
# Indonesia                0.4
# Spain                    0.4
# Sweden                   0.4
# Switzerland              0.4
# Ireland                  0.3
# United Arab Emirates     0.3
# Norway                   0.3
# Belgium                  0.2
# Thailand                 0.2
# Denmark                  0.2
# Philippines              0.2
# Finland                  0.2
# Colombia                 0.2
# South Africa             0.2
# Turkey                   0.2
# Austria                  0.2
# ...

# %%
# Plot geral dos Paises
plt.figure( figsize=(15,6) )
plt.title('Analise dos Paises gerador de Unicornios')
plt.pie(
    Analise,
    labels = Analise.index,
    shadow=True,
    startangle=90,
    autopct='%1.1f%%'
);

# %%
# Plot geral dos Paises (10 principais paises)
plt.figure( figsize=(15,6) )
plt.title('Analise dos Paises gerador de Unicornios - Top 10')
plt.pie(
    Analise.head(10),
    labels = Analise.index[0:10],
    shadow=True,
    startangle=90,
    autopct='%1.1f%%'
);

# %%
# Conversão para Data (antes estava como objeto)
Base_Dados['Data de Adesão'] = pd.to_datetime( Base_Dados['Data de Adesão'] )

Base_Dados['Data de Adesão'].head()
# Out:
# 0   2017-04-07
# 1   2012-12-01
# 2   2014-01-23
# 3   2011-12-12
# 4   2018-01-08
# Name: Data de Adesão, dtype: datetime64[ns]

# %%
# Extrair o Ano e Mes - criando novas colunas
Base_Dados['Mes'] = pd.DatetimeIndex( Base_Dados['Data de Adesão'] ).month
Base_Dados['Ano'] = pd.DatetimeIndex( Base_Dados['Data de Adesão'] ).year

Base_Dados.head()
# Out:
#    Id    Empresa Valor ($) Data de Adesão           Pais         Cidade  \
# 0   0  Bytedance      $140     2017-04-07          China        Beijing
# 1   1     SpaceX    $100.3     2012-12-01  United States      Hawthorne
# 2   2     Stripe       $95     2014-01-23  United States  San Francisco
# 3   3     Klarna     $45.6     2011-12-12         Sweden      Stockholm
# 4   4      Canva       $40     2018-01-08      Australia    Surry Hills
#
#                           Setor  \
# 0       Artificial intelligence
# 1                         Other
# 2                       Fintech
# 3                       Fintech
# 4  Internet software & services
#
#                                         Investidores  Mes   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# 3  Institutional Venture Partners, Sequoia Capita...   12  2011
# ...

# %%
# Tabela Analitica
Analise_Agrupada = Base_Dados.groupby( by=['Pais', 'Ano', 'Mes', 'Empresa'] ).count()['Id'].reset_index()

Analise_Agrupada
# Out:
#                Pais   Ano  Mes        Empresa  Id
# 0         Argentina  2021    8           Uala   1
# 1         Australia  2018    1          Canva   1
# 2         Australia  2019    3      Airwallex   1
# 3         Australia  2021    5  SafetyCulture   1
# 4         Australia  2021    7    Culture Amp   1
# ..              ...   ...  ...            ...  ..
# 931   United States  2021   12   Panther Labs   1
# 932   United States  2021   12     ReliaQuest   1
# 933   United States  2021   12      YipitData   1
# 934  United States,  2021    9     TrialSpark   1
# 935         Vietnam  2021   10      Sky Mavis   1
#
# [936 rows x 5 columns]

# %%
Analise_Agrupada.loc[
  Analise_Agrupada['Pais'] == 'Brazil'
]
# Out:
#       Pais   Ano  Mes           Empresa  Id
# 12  Brazil  2018    3            Nubank   1
# 13  Brazil  2018    7            Movile   1
# 14  Brazil  2018   11             iFood   1
# 15  Brazil  2019    6             Loggi   1
# 16  Brazil  2019    9       QuintoAndar   1
# 17  Brazil  2019   10             EBANX   1
# 18  Brazil  2019   12  Wildlife Studios   1
# 19  Brazil  2020    1              Loft   1
# 20  Brazil  2020   12           C6 Bank   1
# 21  Brazil  2020   12          Creditas   1
# 22  Brazil  2021    1    MadeiraMadeira   1
# 23  Brazil  2021    8         Nuvemshop   1
# 24  Brazil  2021    8             Unico   1
# 25  Brazil  2021    9                 1   1
# 26  Brazil  2021   10            CargoX   1

# %%
# colocando o valor de mercado das empresas brasileiras
# Transformando a coluna Valor (pq tinha um $ antes do valor)
# apply é uma função do pandas que eu consigo mexer linha por linha
# uso função lambda
# substituo $ por nada ''
# pd.to_numeric --> transformando para um float

Base_Dados['Valor ($)'] = pd.to_numeric( Base_Dados['Valor ($)'].apply( lambda Linha: Linha.replace('$', '') ) )

Base_Dados.head()
# Out:
#    Id    Empresa  Valor ($) Data de Adesão           Pais         Cidade  \
# 0   0  Bytedance      140.0     2017-04-07          China        Beijing
# 1   1     SpaceX      100.3     2012-12-01  United States      Hawthorne
# 2   2     Stripe       95.0     2014-01-23  United States  San Francisco
# 3   3     Klarna       45.6     2011-12-12         Sweden      Stockholm
# 4   4      Canva       40.0     2018-01-08      Australia    Surry Hills
#
#                           Setor  \
# 0       Artificial intelligence
# 1                         Other
# 2                       Fintech
# 3                       Fintech
# 4  Internet software & services
#
#                                         Investidores  Mes   Ano
# 0  Sequoia Capital China, SIG Asia Investments, S...    4  2017
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...   12  2012
# 2        Khosla Ventures, LowercaseCapital, capitalG    1  2014
# 3  Institutional Venture Partners, Sequoia Capita...   12  2011
# ...

# %%
# Tabela Analitica
Analise_Pais = Base_Dados.groupby( by=['Pais', 'Setor'] ).sum()['Valor ($)'].reset_index()

Analise_Pais.head()
# Out:
#         Pais                            Setor  Valor ($)
# 0  Argentina                          Fintech       2.45
# 1  Australia  E-commerce & direct-to-consumer       1.00
# 2  Australia                          Fintech       5.50
# 3  Australia     Internet software & services      44.10
# 4    Austria                           Edtech       1.70

# %%
# Tabela Analitica
Analise_Pais = Base_Dados.groupby( by=['Pais'] ).sum()['Valor ($)'].reset_index()

Analise_Pais.head()
# Out:
#         Pais  Valor ($)
# 0  Argentina       2.45
# 1  Australia      50.60
# 2    Austria       5.81
# 3    Belgium       7.55
# 4    Bermuda       1.60

# %%
# ordenando por valor:
Analise_Valor = Analise_Pais.sort_values('Valor ($)', ascending=False)
Analise_Valor.head(20)
# Out:
#               Pais  Valor ($)
# 44   United States    1604.03
# 8            China     569.48
# 43  United Kingdom     150.29
# 18           India     148.45
# 16         Germany      66.63
# 5           Brazil      61.05
# 38          Sweden      58.08
# 1        Australia      50.60
# 22          Israel      43.82
# 17       Hong Kong      41.45
# 6           Canada      37.73
# 15          France      35.61
# 19       Indonesia      26.90
# 36     South Korea      24.69
# 27          Mexico      15.20
# 34       Singapore      14.90
# 28     Netherlands      14.30
# 23           Japan       8.82
# 41          Turkey       8.50
# 3          Belgium       7.55

# %%
# Brasil esta em 9º lugar em gerar unicórnios, mas em 6º em ralação ao valor

# %%
plt.figure( figsize=(15,6) )
plt.plot( Analise_Valor['Pais'], Analise_Valor['Valor ($)'] )
plt.title('Analise do Valor por Pais')
plt.xticks( rotation=45, ha='right');

# %%
# Visualizando com um gráfico de barras
plt.figure( figsize=(15,6) )
plt.title('Analise do Valor por Pais')
plt.bar( Analise_Valor['Pais'], Analise_Valor['Valor ($)']  )
plt.xticks( rotation=45, ha='right' );
